# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('obesity-cleaned.csv')

# %%
data.head(20)
# Out:
#     Unnamed: 0      Country  Year    Obesity (%)         Sex
# 0            0  Afghanistan  1975  0.5 [0.2-1.1]  Both sexes
# 1            1  Afghanistan  1975  0.2 [0.0-0.6]        Male
# 2            2  Afghanistan  1975  0.8 [0.2-2.0]      Female
# 3            3  Afghanistan  1976  0.5 [0.2-1.1]  Both sexes
# 4            4  Afghanistan  1976  0.2 [0.0-0.7]        Male
# 5            5  Afghanistan  1976  0.8 [0.2-2.0]      Female
# 6            6  Afghanistan  1977  0.6 [0.2-1.2]  Both sexes
# 7            7  Afghanistan  1977  0.2 [0.0-0.7]        Male
# 8            8  Afghanistan  1977  0.9 [0.3-2.1]      Female
# 9            9  Afghanistan  1978  0.6 [0.2-1.3]  Both sexes
# 10          10  Afghanistan  1978  0.2 [0.1-0.7]        Male
# 11          11  Afghanistan  1978  0.9 [0.3-2.2]      Female
# 12          12  Afghanistan  1979  0.6 [0.3-1.3]  Both sexes
# 13          13  Afghanistan  1979  0.3 [0.1-0.8]        Male
# 14          14  Afghanistan  1979  1.0 [0.3-2.3]      Female
# 15          15  Afghanistan  1980  0.7 [0.3-1.4]  Both sexes
# 16          16  Afghanistan  1980  0.3 [0.1-0.8]        Male
# 17          17  Afghanistan  1980  1.1 [0.4-2.4]      Female
# 18          18  Afghanistan  1981  0.7 [0.3-1.4]  Both sexes
# 19          19  Afghanistan  1981  0.3 [0.1-0.8]        Male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24066 entries, 0 to 24569
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Number   24066 non-null  int64
#  1   Country  24066 non-null  object
#  2   Year     24066 non-null  int64
#  3   Obesity  24066 non-null  float64
#  4   Sex      24066 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 940.1+ KB

# %%
data['Obesity'].unique()
# Out:
# array(['0.5', '0.2', '0.8', '0.6', '0.9', '0.3', '1.0', '0.7', '1.1',
#        '1.2', '0.4', '1.3', '1.4', '1.5', '1.6', '1.7', '1.8', '1.9',
#        '2.1', '2.2', '2.3', '2.4', '2.6', '2.7', '2.9', '3.0', '3.2',
#        '3.4', '3.6', '3.8', '4.0', '4.2', '4.4', '4.7', '4.9', '2.0',
#        '5.2', '5.4', '5.7', '6.0', '2.5', '6.3', '6.6', '2.8', '7.0',
#        '7.3', '5.5', '7.6', '6.5', '8.6', '6.7', '4.6', '8.8', '6.8',
#        '4.8', '8.9', '5.0', '9.1', '7.2', '9.3', '7.4', '9.5', '5.6',
#        '9.7', '7.8', '5.8', '9.9', '8.0', '10.1', '8.3', '10.3', '8.5',
#        '10.6', '8.7', '10.8', '9.0', '11.0', '11.3', '11.5', '9.8', '7.9',
#        '11.7', '8.2', '12.0', '10.4', '12.2', '10.7', '12.5', '9.2',
#        '12.8', '9.6', '13.1', '10.0', '13.4', '13.7', '12.4', '14.0',
#        '11.2', '14.3', '13.2', '14.7', '13.6', '12.1', '15.0', '12.6',
#        '15.4', '14.5', '15.8', '14.9', '16.2', '16.6', '16.0', '17.1',
#        '16.5', '15.5', '17.5', '17.0', '16.1', '18.0', '17.6', '16.8',
#        '18.4', '18.2', '17.4', '18.9', '18.8', '18.1', '19.4', '19.3',
#        '19.9', '19.5', '20.4', '20.5', '20.2', '20.8', '21.1', '20.9',
#        '21.3', '21.7', '21.6', '21.8', '6.9', '11.1', '3.1', '11.4',
#        '7.7', '11.8', '12.7', '9.4', '4.3', '14.1', '4.5', '14.6', '10.2',
#        '15.2', '5.1', '15.7', '16.3', '16.9', '11.9', '18.7', '13.3',
#        '13.8', '14.8', '15.3', '22.4', '23.0', '23.6', '24.2', '17.9',
#        '24.9', '18.5', '25.5', '19.1', '26.2', '19.6', '12.3', '26.8',
#        '12.9', '27.5', '28.2', '21.4', '28.8', '22.0', '29.5', '22.7',
#        '30.2', '23.3', '30.9', '24.0', '31.5', '24.7', '32.2', '25.3',
#        '17.8', '32.9', '26.0', '33.6', '26.7', '19.2', '34.2', '27.4',
#        '34.9', '13.5', '16.4', '19.8', '20.6', '21.0', '18.6', '19.0',
#        '22.1', '17.3', '22.3', '17.7', '22.5', '22.6', '20.7', '22.8',
#        '21.2', '23.1', '21.5', '23.5', '22.2', '23.8', '23.9', '22.9',
#        '24.1', '23.2', '24.3', '23.4', '24.4', '24.5', '24.6', '24.8',
#        '25.0', '25.1', '25.2', '25.4', '25.6', '25.9', '4.1', '5.3',
#        '5.9', '8.4', '6.2', '7.1', '3.3', '7.5', '11.6', '6.4', '10.9',
#        '3.5', '3.7', '6.1', '13.0', '14.4', '8.1', '15.1', '15.9', '16.7',
#        '23.7', '10.5', '14.2', '17.2', '18.3', '20.3', '20.0', '26.3',
#        '25.8', '27.2', '25.7', '27.6', '27.3', '28.1', '27.8', '28.5',
#        '28.3', '29.0', '13.9', '19.7', '15.6', '26.4', '27.0', '27.7',
#        '26.9', '27.9', '28.4', '28.9', '29.6', '20.1', '21.9', '3.9',
#        '26.5', '28.0', '30.0', '30.5', '31.4', '31.8', '32.3', '32.7',
#        '33.2', '26.6', '27.1', '34.1', '34.5', '35.4', '35.8', '36.3',
#        '36.7', '37.2', '31.0', '37.6', '31.6', '38.1', '28.7', '29.1',
#        '29.4', '29.7', '30.1', '30.4', '30.7', '31.1', '32.1', '32.4',
#        '32.8', '33.5', '33.9', '34.3', '34.7', '35.1', '35.6', '36.0',
#        '29.3', '36.4', '29.8', '36.8', '0.1', '31.3', '26.1', '29.2',
#        '30.3', '28.6', '35.7', '36.9', '30.8', '37.4', '38.0', '32.0',
#        '38.6', '32.6', '39.2', '33.3', '39.8', '40.5', '34.6', '41.1',
#        '35.3', '41.8', '36.1', '42.5', '30.6', '43.2', '37.5', '43.8',
#        '38.3', '44.5', '39.0', '45.2', '39.7', '33.7', '45.8', '40.4',
#        '34.4', '46.4', '41.0', '35.2', '47.0', '47.6', '48.3', '43.3',
#        '37.7', '49.0', '44.1', '49.7', '44.9', '39.6', '50.4', '40.6',
#        '51.1', '46.6', '41.5', '51.9', '47.5', '52.6', '43.5', '53.3',
#        '49.1', '44.4', '53.9', '49.9', '45.3', '54.6', '50.6', '46.2',
#        '55.1', '51.3', '55.7', '52.0', '47.8', '56.2', '48.6', '56.7',
#        '53.2', '49.3', '57.2', '53.8', '50.0', '57.6', '54.3', '50.7',
#        '58.0', '54.9', '58.4', '55.4', '58.8', '55.9', '59.2', '29.9',
#        '35.0', '31.2', '31.9', '33.4', '33.0', '37.0', '33.1', '31.7',
#        '34.8', '35.9', '33.8', '35.5', '36.5', '37.9', '38.4', '38.9',
#        '39.5', '40.0', '32.5', '42.0', '43.1', '37.1', '38.7', '41.3',
#        '36.6', '42.1', '42.9', '38.2', '43.6', '44.2', '40.3', '45.5',
#        '40.9', '46.0', '41.6', '42.2', '47.2', '42.8', '47.7', '48.2',
#        '39.4', '48.8', '44.7', '40.1', '40.8', '49.8', '34.0', '37.8',
#        '38.5', '38.8', '40.2', '42.4', '44.0', '36.2', '44.8', '45.6',
#        '39.1', '42.3', '43.0', '43.7', '45.0', '45.7', '46.3', '46.9',
#        '47.4', '48.0', '48.5', '49.6', '37.3', '50.1', '51.5', '46.1',
#        '46.7', '52.5', '47.3', '53.0', '47.9', '53.4', '48.4', '44.3',
#        '54.8', '55.2', '56.1', '51.8', '47.1', '56.5', '52.4', '56.9',
#        '52.9', '57.3', '42.6', '45.1', '39.3', '50.2', '50.9', 'No',
#        '51.4', '51.7', '45.4', '52.1', '52.7', '53.1', '53.7', '54.1',
#        '54.4', '48.7', '54.7', '49.5', '44.6', '56.0', '50.8', '56.4',
#        '51.2', '57.0', '57.9', '58.2', '58.7', '50.3', '59.0', '59.3',
#        '55.5', '59.6', '59.8', '56.3', '60.1', '60.4', '60.6', '57.4',
#        '60.9', '57.8', '61.1', '61.4', '58.5', '61.6', '58.9', '61.9',
#        '62.1', '56.8', '62.4', '60.0', '62.6', '60.3', '62.9', '60.7',
#        '63.1', '61.0', '63.3', '40.7', '41.4', '46.8', '41.2', '49.2',
#        '43.9', '54.5', '43.4', '49.4', '39.9', '51.0', '48.9', '55.0',
#        '55.6', '56.6', '57.1', '54.2', '55.3', '41.7', '41.9', '48.1',
#        '50.5', '52.2', '52.8', '42.7', '51.6', '46.5'], dtype=object)

# %%
data.columns = (['Number', 'Country', 'Year', 'Obesity', 'Sex'])

data["Obesity"]= data["Obesity"].apply(lambda x: (x.split(" ")[0]))

data = data[data["Obesity"] != "No"]

data['Obesity']= data['Obesity'].apply(lambda x: float(x))

data.head(6)
# Out:
#    Number      Country  Year  Obesity         Sex
# 0       0  Afghanistan  1975      0.5  Both sexes
# 1       1  Afghanistan  1975      0.2        Male
# 2       2  Afghanistan  1975      0.8      Female
# 3       3  Afghanistan  1976      0.5  Both sexes
# 4       4  Afghanistan  1976      0.2        Male
# 5       5  Afghanistan  1976      0.8      Female

# %%
print(data.isnull().sum())
# Out:
# Number     0
# Country    0
# Year       0
# Obesity    0
# Sex        0
# dtype: int64

# %%
sns.heatmap(data.isnull()).set(title = 'Missing Data', xlabel = 'Columns', ylabel = 'Data Points')
# Out:
# [Text(33.0, 0.5, 'Data Points'),
#  Text(0.5, 15.0, 'Columns'),
#  Text(0.5, 1, 'Missing Data')]

# %%
g = sns.pairplot(data[['Country','Year', 'Obesity', 'Sex']])
g.fig.suptitle('Correlations')
plt.show()

# %%
fig = plt.figure(figsize=(12,12))
sns.jointplot(data= data, x= "Obesity", y= 'Year', kind= 'hex', color='coral')
plt.title('Some fat people')
plt.show()
